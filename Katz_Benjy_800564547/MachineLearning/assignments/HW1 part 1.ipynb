# %% [markdown]
# This code reads a file from my Github repo and puts it into a dataframe.

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt


file_path = 'https://github.com/rosenfa/ai/blob/master/news-israel.xlsx?raw=true'
df_israel = pd.read_excel(file_path)
file_path = 'https://github.com/rosenfa/ai/blob/master/news-pal.xlsx?raw=true'
df_pal = pd.read_excel(file_path)

# %% [markdown]
# Israel Basic word cloud

# %%
# Extract the 'Content' column
content = df_israel['Content']

# Combine all the text into a single string
all_text = ' '.join(content.dropna())

# Use CountVectorizer to preprocess the text
vectorizer = CountVectorizer()
X = vectorizer.fit_transform([all_text])

# Get the feature names (words)
feature_names = vectorizer.get_feature_names_out()

# Create a dictionary with words and their corresponding frequencies
word_frequencies = dict(zip(feature_names, X.toarray()[0]))

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_frequencies)

# Display the WordCloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Palestine Basic Word Cloud

# %%
# Extract the 'Content' column
content = df_pal['Content']

# Combine all the text into a single string
all_text = ' '.join(content.dropna())

# Use CountVectorizer to preprocess the text
vectorizer = CountVectorizer()
X = vectorizer.fit_transform([all_text])

# Get the feature names (words)
feature_names = vectorizer.get_feature_names_out()

# Create a dictionary with words and their corresponding frequencies
word_frequencies = dict(zip(feature_names, X.toarray()[0]))

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_frequencies)

# Display the WordCloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# With Stop words taken out

# %%
# Extract the 'Content' column
content = df_israel['Content']


# Combine all the text into a single string
all_text = ' '.join(content.dropna())
#all_text = ' '.join(word for word in all_text.split() if word.lower() not in STOPWORDS)

# Use CountVectorizer to preprocess the text
vectorizer = CountVectorizer(stop_words = 'english')

X = vectorizer.fit_transform([all_text])

# Get the feature names (words)
feature_names = vectorizer.get_feature_names_out()

# Create a dictionary with words and their corresponding frequencies
word_frequencies = dict(zip(feature_names, X.toarray()[0]))

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_frequencies)

# Display the WordCloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Extract the 'Content' column
content = df_pal['Content']


# Combine all the text into a single string
all_text = ' '.join(content.dropna())
#all_text = ' '.join(word for word in all_text.split() if word.lower() not in STOPWORDS)

# Use CountVectorizer to preprocess the text
vectorizer = CountVectorizer(stop_words = 'english')

X = vectorizer.fit_transform([all_text])

# Get the feature names (words)
feature_names = vectorizer.get_feature_names_out()

# Create a dictionary with words and their corresponding frequencies
word_frequencies = dict(zip(feature_names, X.toarray()[0]))

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_frequencies)

# Display the WordCloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Porter Stemmer

# %%
from nltk.stem import PorterStemmer
# Extract the 'Content' column
content = df_israel['Content']


# Combine all the text into a single string
all_text = ' '.join(content.dropna())
print(all_text)
all_text = all_text.split()
def stem(word):
  stemmer = PorterStemmer()
  stemmed_word = stemmer.stem(word)
  #print(word)
  #print(stemmed_word)
  return stemmed_word


# Stem each word individually
stemmed_words = [stem(word) for word in all_text]
all_text = ' '.join(stemmed_words)
#all_text = ' '.join(stemmer.stem(word) for word in all_text)
#print(all_text)
# Use CountVectorizer to preprocess the text
vectorizer = CountVectorizer(stop_words = 'english')

X = vectorizer.fit_transform([all_text])

# Get the feature names (words)
feature_names = vectorizer.get_feature_names_out()

# Create a dictionary with words and their corresponding frequencies
word_frequencies = dict(zip(feature_names, X.toarray()[0]))

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_frequencies)

# Display the WordCloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# %%
from nltk.stem import PorterStemmer
# Extract the 'Content' column
content = df_pal['Content']


# Combine all the text into a single string
all_text = ' '.join(content.dropna())
print(all_text)
all_text = all_text.split()
def stem(word):
  stemmer = PorterStemmer()
  stemmed_word = stemmer.stem(word)
  #print(word)
  #print(stemmed_word)
  return stemmed_word


# Stem each word individually
stemmed_words = [stem(word) for word in all_text]
all_text = ' '.join(stemmed_words)
#all_text = ' '.join(stemmer.stem(word) for word in all_text)
#print(all_text)
# Use CountVectorizer to preprocess the text
vectorizer = CountVectorizer(stop_words = 'english')

X = vectorizer.fit_transform([all_text])

# Get the feature names (words)
feature_names = vectorizer.get_feature_names_out()

# Create a dictionary with words and their corresponding frequencies
word_frequencies = dict(zip(feature_names, X.toarray()[0]))

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_frequencies)

# Display the WordCloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# : Qatar, the mediator in the Gaza truce talks, has confirmed that a humanitarian pause has been agreed on. Hamas says it holds US President Joe Biden and his administration directly responsible for the 'ethnic cleansing' committed by Israeli forces at Gazas al-Shifa Hospital.  s Israeli attacks in the besieged Gaza Strip amount toœwar crimes that cannot be justified as acts ofœself-defence, says Jordans Foreign Minister Ayman Safadi.  s: http://aje.io/p7x2m3 Israeli warplanes and artillery bomb several areas in southern Lebanon. "Israel respects no international laws or conventions."  Qatar PM Sheikh Mohammed bin Abdulrahman al-Thani said Israels actions and siege of al-Shifa hospital in Gaza was a˜crime.  s: http://aje.io/5b1xgr Have you seen content with Indian and Israeli flags that seems like fake news? That could be a troll account working for Indias right-wing government. Heres what you need to know about Indias pro-Israel disinformation campaign. The suffering of children amid the ongoing Israeli genocide in Gaza.#GazaGenocide Thousands of American evangelical Christian leaders say they continue toœfully support Israel, even as Israeli forces kill civilians in Gaza.   Last year, @Dena went to the occupied West Bank to understand the alliance between evangelicals and Israel. Magen Inons parents were killed on October 7 by Hamas. He talks to Al Jazeera about their loss and trying to create hope among communities UN chief Antonio Guterres has decried the loss of thousands of Palestinians civilian s in Israels bombardment of the Gaza Strip.   s: http://aje.io/3gjs9 Jordan King Abdullah says the international community should push for an immediate ceasefire in Gaza to prevent a humanitarian catastrophe caused by Israel's 'ugly war against civilians.'  s: http://aje.io/5b1xgr This Palestinian-American feels guilty for leaving her family behind in Gaza. Israel's capital punishment bill is being advanced by far-right National Security Minister Itamar Ben-Gvir http://aje.io/94mqjn Israel has recalled its ambassador to South Africaœfor consultations ahead of a parliamentary vote to decide the fate of the Israeli embassy.  s: http://aje.io/pbvd83 Palestine supporters energise the World Cup qualifier against Australia” in pictures  s: http://aje.io/pbvd83 Russian President Vladimir Putin will take part in an extraordinary summit of the BRICS group of nations on Tuesday to discuss Israel's war in the besieged Gaza Strip, says The Kremlin.  s: http://aje.io/3gjs9 Palestinians are queuing for clean water in Rafah, Gaza.  s: http://aje.io/7sqhkm "How much more violence, bloodshed and misery will it take before people come to their senses?"UN human rights chief Volker Turk calls for a ceasefire in the besieged Gaza Strip.  s: http://aje.io/kebz8 Thousands of Pakistanis took to the streets in Lahore to  express solidarity with Palestinians in the Gaza Strip.  s: http://aje.io/cxyb1o What Israels video of˜Hamas tunnel under al-Shifa tells us AntÃ³nio Guterres Secretary-General of the United Nations: "The staggering and unacceptable civilian death toll in #Gaza demands an urgent call for an immediate ceasefire on humanitarian grounds." #UN #Israel This is what its like to give birth in Gaza.AJ+ filmed inside Gazas maternity wards before many of them collapsed. I wish I was with them... I wish we would either die or  together.Dina Alalami, a Palestinian residing in Qatar, lost contact with her family in Gaza City after they were targeted by Israeli forces while forcibly fleeing to the south of the Strip http://aje.io/lbvsdp Israeli artillery bombs a house in the village of Houla in southern Lebanon. Israeli occupation soldiers carry out a mass detention campaign in the Tulkarm refugee camp in the occupied West Bank. Ministry of Health in Gaza Spokesman: -Those trapped inside Shifa complex face a dire situation without water, electricity, or food. -Communication loss among hospitals obstructs information s. #Gaza #Israel. "#Gaza was not ...

# %% [markdown]
# Lemmatizer

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
nltk.download('wordnet')


# Extract the 'Content' column
content = df_israel['Content']


# Combine all the text into a single string
all_text = ' '.join(content.dropna())
print(all_text)
all_text = all_text.split()



def lem(word):
  lemmatizer = WordNetLemmatizer()
  lem_word = lemmatizer.lemmatize(word)
  #print(word)
  #print(lem_word)
  return lem_word


# Stem each word individually
lem_words = [lem(word) for word in all_text]
all_text = ' '.join(lem_words)
#all_text = ' '.join(stemmer.stem(word) for word in all_text)
#print(all_text)
# Use CountVectorizer to preprocess the text
vectorizer = CountVectorizer(stop_words = 'english')

X = vectorizer.fit_transform([all_text])

# Get the feature names (words)
feature_names = vectorizer.get_feature_names_out()

# Create a dictionary with words and their corresponding frequencies
word_frequencies = dict(zip(feature_names, X.toarray()[0]))

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_frequencies)

# Display the WordCloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# "06:30," a documentary project filmed in Tel Aviv last week, will recreate the horrors of the Hamas massacre in southern Israel on October 7 through miniature sets and the testimonies of 10 survivors "Fourteen residents of Kibbutz Nahal Oz were murdered, 20 are still missing, and five, including my  brother-in-law are confirmed as hostages".Moshe Emilio Lavi addresses congressmen at the the Capitol. #ICYMI | @IsraelAllies "Releasing the hostages is the supreme task. That’s the most important goal, and politicians aren’t allowed to engage in political manipulation on this matter," Hagai Hadas, Israel's former coordinator for hostages and missing persons, says "Unorthodox" author @Deborah_Feldman has been a vocal critic of Israel in Germany, sparking debate in a country that has been very sensitive to perceptions of antisemitism since the Holocaust.#Unorthodox | #Germany | #Israel "We will have to make difficult decisions in the coming days - defeat Hamas step by step and bring back the hostages," Defense Minister Gallant said on Tuesday after holding a situational assessment at the Gaza Division.#Hamas | #IDF | #Israel #Hamas leader, Ismail Haniyeh, spoke with the secretary general of the #PalestinianIslamicJihad, Ziad Nachala on Monday evening about war developments and the #HostageDeal issues, according to Israeli media.Read more about it here: #NewYork State Senator Julia Salazar fired a staffer who endorsed the Oct. 7 #Hamas attack on #Israel. ‘Israel is not our friend’: Neo-Nazis salute Hitler in march through Wisconsin town israel-is-not-our-friend-neo-nazis-salute-hitler-in-march-through-wisconsin-town/&… .  to read “An opportunity has been identified to create the perfect storm, internal crisis, broad escalation in the Palestinian arena and challenges from other areas": Read the warnings Netanyahu received from Military Intelligence before October 7 1,000 boats said set to leave Turkey for Gaza waters in new ‘Freedom Flotilla’ 1000-boats-said-set-to-leave-turkey-for-gaza-waters-in-new-freedom-flotilla/&… .  to read 1/11November 24, 1998, was a day to remember in the Gaza Strip@avischarf 1/2The head of Military Intelligence's research division warned Netanyahu in March and July that Israel's sociopolitical crisis over the judicial coup was stirring its enemies to chance military action 1/3Despite Mossad director David Barnea meeting Qatari officials in Doha earlier this month to discuss the hostage negotiations, Western public pressure had been building on Qatar’s Hamas office | Opinion 1/4Amidst fierce fighting in the Gaza Strip, X-owner Elon Musk said on Tuesday that the social network would begin channeling a portion of its revenue to support medical care for Israelis and Palestinians@SamuelSokol @Bsamuels0 1/6There’s nothing easier or faster in today’s global media environment than manufacturing a conspiracy theory. We’ve seen one grow in plain sight in recent days: the denial of Hamas’ massacre of Israeli citizens on October 7 / @AnshelPfeffer 10/11A momentary sense of coexistence took wings as Israeli and Palestinian pilots exchanged greetings in English, Hebrew and Arabic while flying over Egyptian airspace 11/11However, the Gaza Strip’s air bridge to the world did not last long. After the outbreak of the Second Intifada in September 2000, Israel shut down the airport, and a year later IDF bulldozers destroyed the runway 2 more US Jewish Democrats join growing calls for a Gaza ceasefire 2-more-us-jewish-democrats-join-growing-calls-for-a-gaza-ceasefire/&… .  to read 2/11Thousands of Palestinians gathered at the southwestern tip, on the Egyptian border, opposite the Kerem Shalom crossing, and watched in awe as large jets from Morocco, Egypt and Jordan landed there 2/2“We are seeing deliberation on whether to sit on the fence and let Israel continue to weaken itself, or to take initiative and worsen its situation,” wrote Brigadier General Amit Sa’ar in letters to Netanyahu 2/2Danielle Haas, who is herself Israeli an ...

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
nltk.download('wordnet')


# Extract the 'Content' column
content = df_pal['Content']


# Combine all the text into a single string
all_text = ' '.join(content.dropna())
print(all_text)
all_text = all_text.split()



def lem(word):
  lemmatizer = WordNetLemmatizer()
  lem_word = lemmatizer.lemmatize(word)
  #print(word)
  #print(lem_word)
  return lem_word


# Stem each word individually
lem_words = [lem(word) for word in all_text]
all_text = ' '.join(lem_words)
#all_text = ' '.join(stemmer.stem(word) for word in all_text)
#print(all_text)
# Use CountVectorizer to preprocess the text
vectorizer = CountVectorizer(stop_words = 'english')

X = vectorizer.fit_transform([all_text])

# Get the feature names (words)
feature_names = vectorizer.get_feature_names_out()

# Create a dictionary with words and their corresponding frequencies
word_frequencies = dict(zip(feature_names, X.toarray()[0]))

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_frequencies)

# Display the WordCloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
